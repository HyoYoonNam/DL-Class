# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
import tensorflow.keras as keras
# Out:
# 2024-10-07 12:19:32.885302: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Table of contents

# %% [markdown]
# ```
# 0. Introduction
# 1. Load the dataset
#     - lying만 있는 train set 분리
#     - lying과 jumping 모두 있는 test set 분리
# 2. Autoencoder
# ```

# %% [markdown]
# ```
# [summary]
#  threshold = 25
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       960
#            1       1.00      1.00      1.00       480
#
#     accuracy                           1.00      1440
#    macro avg       1.00      1.00      1.00      1440
# weighted avg       1.00      1.00      1.00      1440
# ```

# %% [markdown]
# # 0. Introduction

# %% [markdown]
# **Dataset**
# - [DSA](https://github.com/MyungKyuYi/AI-class/blob/main/Pre-trained_model.ipynb)
#
# **Environment**
# - macOS `x86`cpu
#
# **Framework**
# - TensorFlow: Version `2.10.0`
#
# **Dependencies**
# - Python: Version `3.9.18`
# - Numpy: Version `1.26.4`
# - Pandas: Version `2.2.2`
# - Matplotlib: Version `3.9.2`
# - scikit-learn: Version `1.5.1`
#
# **Purpose**
# - DSA데이터에서 lyingRigh 480개 + lyingBack 480개를 정상 (normal), jumping 480개를 비정상(abnormal) 데이터로 사용
# - 두개 (lying+jumping) activity를 섞어서 test set으로 사용
# - lying(Righ, Back)만 가지고 훈련하여 AE 구축
# - 테스트 데이터(lying+jumping)를 AE에 넣어서 Reconstruction error(입력/출력차이)를 구함
# - 적당한 threshold값으로 분류수행
# - accuracy를 구함
#
# **References**
# - \-

# %% [markdown]
# # 1. Load the dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# !ls ./datasets
# Out:
# DSA_features.csv  abalone.csv       breast_cancer.csv diabetes.csv
# HAR               ae_data.csv       creditcard.csv    아카이브.zip

# %%
df = pd.read_csv('./datasets/DSA_features.csv')
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %%
np.unique(df['activity'])
# Out:
# array(['ascendingStairs', 'basketBall', 'crossTrainer',
#        'cyclingHorizontal', 'cyclingVertical', 'decendingStairs',
#        'jumping', 'lyingBack', 'lyingRigh', 'movingInElevator', 'rowing',
#        'runningTreadmill', 'sitting', 'standing',
#        'standingInElevatorStill', 'stepper', 'walkingLot',
#        'walkingTreadmillFlat', 'walkingTreadmillIncline'], dtype=object)

# %%
df_train = df[(df['activity'] == 'lyingBack') | (df['activity'] == 'lyingRigh')]
print(f'df_train.shape: {df_train.shape} \ndf_train.unique: {np.unique(df_train["activity"])}')
df_train
# Out:
# df_train.shape: (960, 272)
# df_train.unique: ['lyingBack' 'lyingRigh']
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 960     -4.834646     -4.7185     -4.9049    0.001124    0.033529
# 961     -4.780810     -4.5850     -4.8833    0.003948    0.062835
# 962     -4.804400     -4.7037     -4.8755    0.001482    0.038496
# 963     -4.750563     -4.5696     -4.8977    0.004447    0.066683
# 964     -4.774916     -4.6741     -4.8457    0.001080    0.032868
# ...           ...         ...         ...         ...         ...
# 1915     2.620502      2.6592      2.5891    0.000199    0.014113
# 1916     2.613423      2.6572      2.5815    0.000207    0.014387
# 1917     2.614750      2.6576      2.5654    0.000257    0.016018
# 1918     2.620167      2.6589      2.5781    0.000216    0.014691
# 1919     2.615565      2.6789      2.5734    0.000310    0.017610
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 960      0.632141    -0.501018    -0.41744    -0.59561    0.001016  ...
# 961      1.052880    -0.480601    -0.40372    -0.63184    0.001297  ...
# 962      0.735226    -0.493925    -0.42616    -0.59561    0.000863  ...
# 963      0.710263    -0.437358    -0.30877    -0.55225    0.003587  ...
# 964      0.324779    -0.459456    -0.38900    -0.53714    0.001059  ...
# ...           ...          ...         ...         ...         ...  ...
# 1915     0.148452    -9.392025    -9.34240    -9.42070    0.000242  ...
# 1916     0.368746    -9.398851    -9.36570    -9.43560    0.000156  ...
# 1917    -0.007991    -9.397350    -9.36280    -9.43130    0.000214  ...
# 1918    -0.114904    -9.397014    -9.36490    -9.45390    0.000257  ...
# 1919     0.608394    -9.398614    -9.36610    -9.42790    0.000167  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 960      0.000986      0.074676     -0.532664     -0.52993     -0.53521
# 961      0.000788     -0.181526     -0.531169     -0.52940     -0.53365
# 962      0.000677     -0.263115     -0.530569     -0.52873     -0.53222
# 963      0.000686     -0.060925     -0.531167     -0.52962     -0.53283
# 964      0.000739      0.335811     -0.529804     -0.52706     -0.53251
# ...           ...           ...           ...          ...          ...
# 1915     0.009589      0.401254     -0.410987     -0.38221     -0.44605
# 1916     0.008588      0.147180     -0.411248     -0.36581     -0.43676
# 1917     0.005814      0.032341     -0.409787     -0.37926     -0.43431
# 1918     0.009510      0.409508     -0.409101     -0.36074     -0.44087
# 1919     0.009874      0.413339     -0.410440     -0.38588     -0.43841
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew   activity  people
# 960   9.585668e-07     0.000979     -0.193301  lyingBack      p1
# 961   7.608973e-07     0.000872     -0.372381  lyingBack      p1
# 962   5.160537e-07     0.000718      0.185587  lyingBack      p1
# 963   4.975523e-07     0.000705     -0.145321  lyingBack      p1
# 964   1.292131e-06     0.001137     -0.026271  lyingBack      p1
# ...            ...          ...           ...        ...     ...
# 1915  9.935077e-05     0.009967     -0.597598  lyingRigh      p8
# 1916  8.659481e-05     0.009306      1.021454  lyingRigh      p8
# 1917  7.258946e-05     0.008520      0.431012  lyingRigh      p8
# 1918  1.127801e-04     0.010620      1.368666  lyingRigh      p8
# 1919  7.216993e-05     0.008495      0.054973  lyingRigh      p8
#
# [960 rows x 272 columns]

# %%
# 정상 샘플만 있는 X_train
# lyingBack과 lyingRigh를 모두 0(Normal)로 변경
df_train.loc[:, 'activity'] = 0

# %%
# X인 동시에 y. self supervised learning
X_train = df_train.drop(['activity', 'people'], axis=1).to_numpy()
print(f'X_train.shape: {X_train.shape}')
# Out:
# X_train.shape: (960, 270)

# %%
df_test = df[(df['activity'] == 'lyingBack') | (df['activity'] == 'lyingRigh') | (df['activity'] == 'jumping')]
print(f'df_test.shape: {df_test.shape} \ndf_test.unique: {np.unique(df_test["activity"])}')
df_test
# Out:
# df_test.shape: (1440, 272)
# df_test.unique: ['jumping' 'lyingBack' 'lyingRigh']
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 960     -4.834646     -4.7185     -4.9049    0.001124    0.033529
# 961     -4.780810     -4.5850     -4.8833    0.003948    0.062835
# 962     -4.804400     -4.7037     -4.8755    0.001482    0.038496
# 963     -4.750563     -4.5696     -4.8977    0.004447    0.066683
# 964     -4.774916     -4.6741     -4.8457    0.001080    0.032868
# ...           ...         ...         ...         ...         ...
# 8635     9.298029     32.4980     -6.0782  134.634624   11.603216
# 8636     8.738784     34.0480     -6.7822  145.225186   12.050941
# 8637     9.404261     34.8670     -5.3331  130.142955   11.408022
# 8638     9.139112     32.5060     -6.8835  135.812815   11.653876
# 8639     8.868404     30.9070     -6.7151  128.743919   11.346538
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 960      0.632141    -0.501018    -0.41744    -0.59561    0.001016  ...
# 961      1.052880    -0.480601    -0.40372    -0.63184    0.001297  ...
# 962      0.735226    -0.493925    -0.42616    -0.59561    0.000863  ...
# 963      0.710263    -0.437358    -0.30877    -0.55225    0.003587  ...
# 964      0.324779    -0.459456    -0.38900    -0.53714    0.001059  ...
# ...           ...          ...         ...         ...         ...  ...
# 8635     0.570723    -2.592341     1.73230   -12.91800    9.207424  ...
# 8636     0.760224    -2.417799     1.19030   -10.90200    9.233904  ...
# 8637     0.560963    -2.408945     0.81347    -8.21750    6.635468  ...
# 8638     0.589304    -2.359531     1.32350    -9.57930    7.510565  ...
# 8639     0.585457    -2.144665     0.93113    -8.52640    6.022491  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 960      0.000986      0.074676     -0.532664     -0.52993     -0.53521
# 961      0.000788     -0.181526     -0.531169     -0.52940     -0.53365
# 962      0.000677     -0.263115     -0.530569     -0.52873     -0.53222
# 963      0.000686     -0.060925     -0.531167     -0.52962     -0.53283
# 964      0.000739      0.335811     -0.529804     -0.52706     -0.53251
# ...           ...           ...           ...          ...          ...
# 8635     0.030501      0.334449      0.625187      0.69130      0.57187
# 8636     0.031573      0.396417      0.624749      0.69356      0.57040
# 8637     0.030322      0.524964      0.631822      0.69012      0.58197
# 8638     0.024060      0.301200      0.624196      0.68856      0.57362
# 8639     0.023166      0.395776      0.633913      0.69286      0.58642
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew   activity  people
# 960   9.585668e-07     0.000979     -0.193301  lyingBack      p1
# 961   7.608973e-07     0.000872     -0.372381  lyingBack      p1
# 962   5.160537e-07     0.000718      0.185587  lyingBack      p1
# 963   4.975523e-07     0.000705     -0.145321  lyingBack      p1
# 964   1.292131e-06     0.001137     -0.026271  lyingBack      p1
# ...            ...          ...           ...        ...     ...
# 8635  9.188517e-04     0.030313      0.274486    jumping      p8
# 8636  9.632708e-04     0.031037      0.433661    jumping      p8
# 8637  8.933477e-04     0.029889      0.335023    jumping      p8
# 8638  1.025797e-03     0.032028      0.272121    jumping      p8
# 8639  9.165240e-04     0.030274      0.342332    jumping      p8
#
# [1440 rows x 272 columns]

# %%
# 정상 sample과 비정상 sample이 모두 있는 X_test
# lyingBack과 lyingRigh를 모두 0(Normal)로 변경
# jumping은 1(Abnormal)로 변경
df_test.loc[df_test['activity'].isin(['lyingBack', 'lyingRigh']), 'activity'] = 0
df_test.loc[df_test['activity'] == 'jumping', 'activity'] = 1

# 기존에 y_test는 string value가 있었기 때문에 dtype이 object임
# 이를 위에서 숫자로 바꿔줬어도 object dtype에 숫자를 담을 수 있기에 여전히 object dtype으로 유지
# 이후 연산을 위해서 dtype을 int로 변경
df_test['activity'] = df_test['activity'].astype(int)
# Out:
# /var/folders/m_/5z28qmvj575cs_9xldf0gyd80000gn/T/ipykernel_5515/688263516.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['activity'] = df_test['activity'].astype(int)

# %%
# test set의 경우 accuracy 평가를 위해서 기존 y를 남겨둠
X_test = df_test.drop(['activity', 'people'], axis=1).to_numpy()
y_test = df_test['activity'].to_numpy()

# # string -> int로 바꾸는 LabelEncoder 사용
# from sklearn.preprocessing import LabelEncoder
# label_encoder = LabelEncoder()
# y_test_labeled = label_encoder.fit_transform(y_test)

# print(f'X_test.shape: {X_test.shape}')
# print(f'Before LabelEncode: {np.unique(df_test["activity"])}')
# print(f'After LabelEncode: {np.unique(y_test_labeled)} \n')
# print(f'y_test_labeled.head() \n{y_test_labeled[:5]}')

# %%
# # one-hot encoding
# y_test_hot = keras.utils.to_categorical(y_test_labeled)
# print(f'y_test_hot.head() \n{y_test_hot[:5]}')

# %% [markdown]
# # 2. Autoencoder

# %%
import tensorflow as tf
import tensorflow.keras as keras

# %%
input_dim = X_train.shape[1]
encoding_dim = int(input_dim / 2)
bottleneck_dim = int(encoding_dim / 2)

num_epochs = 50
batch_size = 32

# %%
autoencoder = keras.Sequential(name='autoencoder')
# encoder
autoencoder.add(keras.layers.Input(shape=(input_dim,)))
autoencoder.add(keras.layers.Dense(encoding_dim, activation='relu'))
autoencoder.add(keras.layers.Dense(bottleneck_dim, activation='relu'))
# decoder
autoencoder.add(keras.layers.Dense(bottleneck_dim, activation='relu'))
autoencoder.add(keras.layers.Dense(encoding_dim, activation='relu'))
autoencoder.add(keras.layers.Dense(input_dim, activation='sigmoid'))

autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 135)               36585
#
#  dense_1 (Dense)             (None, 67)                9112
#
#  dense_2 (Dense)             (None, 67)                4556
#
#  dense_3 (Dense)             (None, 135)               9180
#
#  dense_4 (Dense)             (None, 270)               36720
#
# =================================================================
# Total params: 96,153
# Trainable params: 96,153
# Non-trainable params: 0
# _________________________________________________________________
# 2024-10-07 12:20:22.193468: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
autoencoder.compile(optimizer='adam',
                    loss='mse')

# %%
history = autoencoder.fit(X_train, X_train,
                          validation_split=0.1,
                          epochs=num_epochs,
                          batch_size=batch_size,
                          shuffle=True,
                          verbose=2)
# Out:
# Epoch 1/50
# 27/27 - 0s - loss: 5.2202 - val_loss: 4.8979 - 475ms/epoch - 18ms/step
# Epoch 2/50
# 27/27 - 0s - loss: 4.8743 - val_loss: 4.8681 - 52ms/epoch - 2ms/step
# Epoch 3/50
# 27/27 - 0s - loss: 4.8583 - val_loss: 4.8930 - 56ms/epoch - 2ms/step
# Epoch 4/50
# 27/27 - 0s - loss: 4.8533 - val_loss: 4.8877 - 53ms/epoch - 2ms/step
# Epoch 5/50
# 27/27 - 0s - loss: 4.8498 - val_loss: 4.8767 - 56ms/epoch - 2ms/step
# Epoch 6/50
# 27/27 - 0s - loss: 4.8485 - val_loss: 4.8776 - 63ms/epoch - 2ms/step
# Epoch 7/50
# 27/27 - 0s - loss: 4.8475 - val_loss: 4.8840 - 57ms/epoch - 2ms/step
# Epoch 8/50
# 27/27 - 0s - loss: 4.8445 - val_loss: 4.8871 - 58ms/epoch - 2ms/step
# Epoch 9/50
# 27/27 - 0s - loss: 4.8408 - val_loss: 4.8895 - 55ms/epoch - 2ms/step
# Epoch 10/50
# 27/27 - 0s - loss: 4.8386 - val_loss: 4.8878 - 56ms/epoch - 2ms/step
# Epoch 11/50
# 27/27 - 0s - loss: 4.8379 - val_loss: 4.8971 - 57ms/epoch - 2ms/step
# Epoch 12/50
# 27/27 - 0s - loss: 4.8354 - val_loss: 4.9033 - 57ms/epoch - 2ms/step
# Epoch 13/50
# 27/27 - 0s - loss: 4.8338 - val_loss: 4.8992 - 52ms/epoch - 2ms/step
# Epoch 14/50
# 27/27 - 0s - loss: 4.8333 - val_loss: 4.9049 - 56ms/epoch - 2ms/step
# Epoch 15/50
# 27/27 - 0s - loss: 4.8323 - val_loss: 4.9018 - 54ms/epoch - 2ms/step
# Epoch 16/50
# 27/27 - 0s - loss: 4.8317 - val_loss: 4.8988 - 52ms/epoch - 2ms/step
# Epoch 17/50
# 27/27 - 0s - loss: 4.8316 - val_loss: 4.9024 - 55ms/epoch - 2ms/step
# Epoch 18/50
# 27/27 - 0s - loss: 4.8310 - val_loss: 4.8986 - 53ms/epoch - 2ms/step
# Epoch 19/50
# 27/27 - 0s - loss: 4.8309 - val_loss: 4.9037 - 56ms/epoch - 2ms/step
# Epoch 20/50
# 27/27 - 0s - loss: 4.8303 - val_loss: 4.9016 - 52ms/epoch - 2ms/step
# Epoch 21/50
# 27/27 - 0s - loss: 4.8299 - val_loss: 4.9031 - 53ms/epoch - 2ms/step
# Epoch 22/50
# 27/27 - 0s - loss: 4.8298 - val_loss: 4.9134 - 56ms/epoch - 2ms/step
# Epoch 23/50
# 27/27 - 0s - loss: 4.8293 - val_loss: 4.9056 - 59ms/epoch - 2ms/step
# Epoch 24/50
# 27/27 - 0s - loss: 4.8290 - val_loss: 4.9026 - 55ms/epoch - 2ms/step
# Epoch 25/50
# 27/27 - 0s - loss: 4.8289 - val_loss: 4.9026 - 52ms/epoch - 2ms/step
# Epoch 26/50
# 27/27 - 0s - loss: 4.8282 - val_loss: 4.9093 - 52ms/epoch - 2ms/step
# Epoch 27/50
# 27/27 - 0s - loss: 4.8281 - val_loss: 4.9092 - 55ms/epoch - 2ms/step
# Epoch 28/50
# 27/27 - 0s - loss: 4.8279 - val_loss: 4.9047 - 67ms/epoch - 2ms/step
# Epoch 29/50
# 27/27 - 0s - loss: 4.8272 - val_loss: 4.9080 - 60ms/epoch - 2ms/step
# Epoch 30/50
# 27/27 - 0s - loss: 4.8258 - val_loss: 4.9014 - 58ms/epoch - 2ms/step
# Epoch 31/50
# 27/27 - 0s - loss: 4.8255 - val_loss: 4.9062 - 52ms/epoch - 2ms/step
# Epoch 32/50
# 27/27 - 0s - loss: 4.8250 - val_loss: 4.8994 - 61ms/epoch - 2ms/step
# Epoch 33/50
# 27/27 - 0s - loss: 4.8248 - val_loss: 4.8964 - 53ms/epoch - 2ms/step
# Epoch 34/50
# 27/27 - 0s - loss: 4.8248 - val_loss: 4.8953 - 62ms/epoch - 2ms/step
# Epoch 35/50
# 27/27 - 0s - loss: 4.8247 - val_loss: 4.8970 - 59ms/epoch - 2ms/step
# Epoch 36/50
# 27/27 - 0s - loss: 4.8245 - val_loss: 4.8945 - 58ms/epoch - 2ms/step
# Epoch 37/50
# 27/27 - 0s - loss: 4.8245 - val_loss: 4.8969 - 57ms/epoch - 2ms/step
# Epoch 38/50
# 27/27 - 0s - loss: 4.8245 - val_loss: 4.8937 - 60ms/epoch - 2ms/step
# Epoch 39/50
# 27/27 - 0s - loss: 4.8238 - val_loss: 4.8891 - 56ms/epoch - 2ms/step
# Epoch 40/50
# 27/27 - 0s - loss: 4.8235 - val_loss: 4.8865 - 62ms/epoch - 2ms/step
# Epoch 41/50
# 27/27 - 0s - loss: 4.8234 - val_loss: 4.8894 - 54ms/epoch - 2ms/step
# Epoch 42/50
# 27/27 - 0s - loss: 4.8211 - val_loss: 4.8975 - 60ms/epoch - 2ms/step
# Epoch 43/50
# 27/27 - 0s - loss: 4.8207 - val_loss: 4.8946 - 55ms/epoch - 2ms/step
# Epoch 44/50
# 27/27 - 0s - loss: 4.8205 - val_loss: 4.8953 - 59ms/epoch - 2ms/step
# Epoch 45/50
# 27/27 - 0s - loss: 4.8203 - val_loss: 4.8936 - 56ms/epoch - 2ms/step
# Epoch 46/50
# 27/27 - 0s - loss: 4.8203 - val_loss: 4.8901 - 53ms/epoch - 2ms/step
# Epoch 47/50
# 27/27 - 0s - loss: 4.8202 - val_loss: 4.8922 - 54ms/epoch - 2ms/step
# Epoch 48/50
# 27/27 - 0s - loss: 4.8202 - val_loss: 4.8919 - 59ms/epoch - 2ms/step
# Epoch 49/50
# 27/27 - 0s - loss: 4.8202 - val_loss: 4.8827 - 63ms/epoch - 2ms/step
# Epoch 50/50
# 27/27 - 0s - loss: 4.8201 - val_loss: 4.8715 - 59ms/epoch - 2ms/step

# %%
# epoch에 따른 loss
loss = history.history['loss']
val_loss = history.history['val_loss']
plt.plot(loss, label = 'train')
plt.plot(val_loss, label = 'val')
plt.title('loss')
plt.legend() # 우측 상단에 그래프 정보 띄워주는 거
plt.show()

# %%
# X_test에 대한 reconstruced data
predictions = autoencoder.predict(X_test) 
# original data와 reconstruced data의 MSE 즉, reconstruction error
mse = np.mean(np.power(X_test - predictions, 2), axis=1) 
                                                                                   
# reconstruction error에 따른 Fraud 여부를 저장할 dataframe 생성
error_df = pd.DataFrame({'Reconstruction_error': mse, # reconstruction error와
                        'True_class': y_test})        # 그때의 Jumping 여부

error_df
# Out:
# 45/45 [==============================] - 0s 828us/step
#       Reconstruction_error  True_class
# 0                 4.655205           0
# 1                 4.647607           0
# 2                 4.642969           0
# 3                 4.665264           0
# 4                 4.652868           0
# ...                    ...         ...
# 1435            668.313030           1
# 1436            591.068183           1
# 1437            514.913461           1
# 1438            485.183100           1
# 1439            457.988140           1
#
# [1440 rows x 2 columns]

# %%
# threshold 값을 조정하여 최선의 정확도를 얻음, 그래프를 보고 결정
# 일단 reconstruction error가 25를 넘으면 Jumping로 분류하도록 설정
threshold = 25

# %%
# y값 필터링
# error_df_test = error_df_test.reset_index()

groups = error_df.groupby('True_class')  # True_class별로 그룹화

fig, ax = plt.subplots()

# 각 클래스 그룹에 대해 점들을 플로팅
for name, group in groups:
    ax.plot(group.index, group.Reconstruction_error, marker='o', ms=3.5, linestyle='',
            label="Jumping" if name == 1 else "Normal(Lying)")

# 고정된 임계값을 빨간 선으로 표시
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')

# Y축 범위를 100 이하로 설정
ax.set_ylim(0, 150)

# 범례, 제목, 축 레이블 설정
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show()

# %% [markdown]
# > Threshold가 25일 때, Normal과 Jumping 구분을 충분히 잘 하고 있음.

# %%
from sklearn.metrics import confusion_matrix, classification_report

LABELS = ['Normal(0)', 'Jumping(1)']
y_pred = [1 if e > threshold else 0 for e in error_df.Reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.True_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(np.array(error_df.True_class), np.array(y_pred)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       960
#            1       1.00      1.00      1.00       480
#
#     accuracy                           1.00      1440
#    macro avg       1.00      1.00      1.00      1440
# weighted avg       1.00      1.00      1.00      1440

# %% [markdown]
# * * *
# ```cf.
# precision   | TP / (TP + FP)
# recall      | TP / (TP + FN)
# f1-score    | harmonic mean of precision and recall
#               (2 * (precision * recall)) / (precision + recall)
#               일반적으로 precision과 recall은 trade-off 관계라서 이를 절충할 수 있도록 한 개념임
# support     | 각 class의 sample count
# accuracy    | (TP + TN) / (TP + TN + FP + FN)
# macro avg   | arithmatic mean of precision(각 class들의 precision 평균)
# ```

# %% [markdown]
# ```cf.
# TN  | True Negative(진음성)
# FN  | False Negative(위음성)
# FP  | False Positive(위양성)
# TP  | True Positive(진양성)
# ```
